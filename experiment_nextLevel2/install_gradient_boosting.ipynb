# %% [markdown]
# # Install Gradient Boosting Libraries
#
# Run this notebook ONCE to install all required gradient boosting libraries.
#
# ## Libraries to Install:
# 1. **XGBoost** - eXtreme Gradient Boosting
# 2. **LightGBM** - Light Gradient Boosting Machine
# 3. **CatBoost** - Categorical Boosting
#
# ## Installation Time:
# - Total: ~2-5 minutes
# - XGBoost: ~1 minute
# - LightGBM: ~1 minute
# - CatBoost: ~1-2 minutes

# %%
# Install XGBoost
print("📦 Installing XGBoost...")
# !pip install xgboost
print("✅ XGBoost installed!\n")
# Out:
# 📦 Installing XGBoost...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#     --------------------------------------- 1.0/72.0 MB 12.2 MB/s eta 0:00:06
#    -- ------------------------------------- 4.2/72.0 MB 14.1 MB/s eta 0:00:05
#    --- ------------------------------------ 6.6/72.0 MB 13.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 9.7/72.0 MB 13.8 MB/s eta 0:00:05
#    ------ --------------------------------- 12.6/72.0 MB 13.6 MB/s eta 0:00:05
#    -------- ------------------------------- 15.2/72.0 MB 13.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 18.1/72.0 MB 13.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 20.7/72.0 MB 13.5 MB/s eta 0:00:04
#    ------------- -------------------------- 23.6/72.0 MB 13.6 MB/s eta 0:00:04
#    -------------- ------------------------- 26.2/72.0 MB 13.5 MB/s eta 0:00:04
# ...

# %%
# Install LightGBM
print("📦 Installing LightGBM...")
# !pip install lightgbm
print("✅ LightGBM installed!\n")
# Out:
# 📦 Installing LightGBM...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------------------------------ --- 1.3/1.5 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 11.6 MB/s  0:00:00
# ...
# ✅ LightGBM installed!

# %%
# Install CatBoost
print("📦 Installing CatBoost...")
# !pip install catboost
print("✅ CatBoost installed!\n")
# Out:
# 📦 Installing CatBoost...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/102.4 MB ? eta -:--:--
#     --------------------------------------- 1.6/102.4 MB 10.3 MB/s eta 0:00:10
#    - -------------------------------------- 4.5/102.4 MB 12.5 MB/s eta 0:00:08
#    -- ------------------------------------- 7.1/102.4 MB 12.1 MB/s eta 0:00:08
#    --- ------------------------------------ 9.7/102.4 MB 12.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 12.6/102.4 MB 12.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 15.2/102.4 MB 12.4 MB/s eta 0:00:08
#    ------- -------------------------------- 18.1/102.4 MB 12.6 MB/s eta 0:00:07
#    -------- ------------------------------- 21.0/102.4 MB 12.7 MB/s eta 0:00:07
#    --------- ------------------------------ 23.9/102.4 MB 12.9 MB/s eta 0:00:07
#    ---------- ----------------------------- 26.5/102.4 MB 12.7 MB/s eta 0:00:06
# ...

# %%
# Verify installations
print("🔍 Verifying installations...\n")

try:
    import xgboost as xgb
    print(f"✅ XGBoost version: {xgb.__version__}")
except ImportError as e:
    print(f"❌ XGBoost not found: {e}")

try:
    import lightgbm as lgb
    print(f"✅ LightGBM version: {lgb.__version__}")
except ImportError as e:
    print(f"❌ LightGBM not found: {e}")

try:
    import catboost
    print(f"✅ CatBoost version: {catboost.__version__}")
except ImportError as e:
    print(f"❌ CatBoost not found: {e}")

print("\n" + "="*60)
print("🎉 All gradient boosting libraries installed successfully!")
print("="*60)
print("\nYou can now run: ai_classifier_step6_gradient_boosting.ipynb")
# Out:
# 🔍 Verifying installations...
#
# ✅ XGBoost version: 3.1.3
# ✅ LightGBM version: 4.6.0
# ✅ CatBoost version: 1.2.8
#
# ...
# 🎉 All gradient boosting libraries installed successfully!
# ...
#
# You can now run: ai_classifier_step6_gradient_boosting.ipynb

# %% [markdown]
# ## ✅ Installation Complete!
#
# ### Next Steps:
# 1. Close this notebook
# 2. Open `ai_classifier_step6_gradient_boosting.ipynb`
# 3. Run all cells
#
# ### Troubleshooting:
# If you get errors:
# - **Restart kernel** (Kernel → Restart)
# - Try installing one by one
# - Check Python version (requires Python 3.7+)
